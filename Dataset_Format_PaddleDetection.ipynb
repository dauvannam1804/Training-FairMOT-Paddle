# %% [markdown]
# <a href="https://colab.research.google.com/github/dauvannam1804/Training-FairMOT-Paddle/blob/main/Dataset_Format_PaddleDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dauvannam1804/PaddleDetection.git
# Out:
# Cloning into 'PaddleDetection'...
# remote: Enumerating objects: 28081, done.
# remote: Counting objects: 100% (581/581), done.
# remote: Compressing objects: 100% (348/348), done.
# remote: Total 28081 (delta 352), reused 388 (delta 233), pack-reused 27500 (from 1)
# Receiving objects: 100% (28081/28081), 312.07 MiB | 22.77 MiB/s, done.
# Resolving deltas: 100% (20750/20750), done.

# %% [markdown]
# **First, download the image_lists.zip using the following command, and unzip them into PaddleDetection/dataset/mot:**

# %%
# !wget https://bj.bcebos.com/v1/paddledet/data/mot/image_lists.zip
# Out:
# --2024-12-03 12:56:02--  https://bj.bcebos.com/v1/paddledet/data/mot/image_lists.zip
# Resolving bj.bcebos.com (bj.bcebos.com)... 103.235.47.176, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to bj.bcebos.com (bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4331342 (4.1M) [application/zip]
# Saving to: ‘image_lists.zip’
#
# image_lists.zip     100%[===================>]   4.13M  7.52MB/s    in 0.5s
#
# 2024-12-03 12:56:04 (7.52 MB/s) - ‘image_lists.zip’ saved [4331342/4331342]

# %%
# !unzip -o "/content/image_lists.zip" -d "/content/PaddleDetection/dataset/mot"
# Out:
# Archive:  /content/image_lists.zip
#    creating: /content/PaddleDetection/dataset/mot/image_lists/
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/bdd100kdet_vehicle.train
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/ht21.train
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/mot17.half
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/bdd100k_mcmot.val
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/cuhksysu.val
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/caltech.all
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/bdd100kmot_vehicle.train
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/mot20.train
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/crowdhuman.train
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/visdrone_vehicle.val
#   inflating: /content/PaddleDetection/dataset/mot/image_lists/pathtrack.train
# ...

# %% [markdown]
# **Then, download the MIX dataset using the following command, and unzip them into PaddleDetection/dataset/mot:**

# %% [markdown]
# Kiểm tra file nào nhẹ nhất để tải thử

# %%
# !wget --spider https://bj.bcebos.com/v1/paddledet/data/mot/MOT17.zip
# !wget --spider https://bj.bcebos.com/v1/paddledet/data/mot/Caltech.zip
# !wget --spider https://bj.bcebos.com/v1/paddledet/data/mot/CUHKSYSU.zip
# !wget --spider https://bj.bcebos.com/v1/paddledet/data/mot/PRW.zip
# !wget --spider https://bj.bcebos.com/v1/paddledet/data/mot/Cityscapes.zip
# !wget --spider https://bj.bcebos.com/v1/paddledet/data/mot/ETHZ.zip
# !wget --spider https://bj.bcebos.com/v1/paddledet/data/mot/MOT16.zip
# Out:
# Spider mode enabled. Check if remote file exists.
# --2024-12-03 12:56:04--  https://bj.bcebos.com/v1/paddledet/data/mot/MOT17.zip
# Resolving bj.bcebos.com (bj.bcebos.com)... 103.235.47.176, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to bj.bcebos.com (bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2388186946 (2.2G) [application/zip]
# Remote file exists.
#
# Spider mode enabled. Check if remote file exists.
# --2024-12-03 12:56:05--  https://bj.bcebos.com/v1/paddledet/data/mot/Caltech.zip
# Resolving bj.bcebos.com (bj.bcebos.com)... 103.235.47.176, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to bj.bcebos.com (bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11907676879 (11G) [application/zip]
# Remote file exists.
#
# Spider mode enabled. Check if remote file exists.
# --2024-12-03 12:56:05--  https://bj.bcebos.com/v1/paddledet/data/mot/CUHKSYSU.zip
# ...

# %%
# !wget https://bj.bcebos.com/v1/paddledet/data/mot/MOT16.zip
# Out:
# --2024-12-03 12:56:07--  https://bj.bcebos.com/v1/paddledet/data/mot/MOT16.zip
# Resolving bj.bcebos.com (bj.bcebos.com)... 103.235.47.176, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to bj.bcebos.com (bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1967897988 (1.8G) [application/zip]
# Saving to: ‘MOT16.zip’
#
# MOT16.zip           100%[===================>]   1.83G  54.5MB/s    in 33s
#
# 2024-12-03 12:56:41 (56.1 MB/s) - ‘MOT16.zip’ saved [1967897988/1967897988]

# %%
# !unzip -o "/content/MOT16.zip" -d "/content/PaddleDetection/dataset/mot"
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/PaddleDetection/dataset/mot/MOT16/images/train/MOT16-04/img1/000230.jpg
#   inflating: /content/PaddleDetection/dataset/mot/MOT16/images/train/MOT16-04/img1/000343.jpg
#   inflating: /content/PaddleDetection/dataset/mot/MOT16/images/train/MOT16-04/img1/000233.jpg
#   inflating: /content/PaddleDetection/dataset/mot/MOT16/images/train/MOT16-04/img1/000494.jpg
#   inflating: /content/PaddleDetection/dataset/mot/MOT16/images/train/MOT16-04/img1/000289.jpg
#   inflating: /content/PaddleDetection/dataset/mot/MOT16/images/train/MOT16-04/img1/000533.jpg
#   inflating: /content/PaddleDetection/dataset/mot/MOT16/images/train/MOT16-04/img1/000730.jpg
#   inflating: /content/PaddleDetection/dataset/mot/MOT16/images/train/MOT16-04/img1/000211.jpg
#   inflating: /content/PaddleDetection/dataset/mot/MOT16/images/train/MOT16-04/img1/000179.jpg
# ...

# %%
# %cd "/content/PaddleDetection/dataset/mot"
# !python gen_labels_MOT.py
# Out:
# /content/PaddleDetection/dataset/mot
